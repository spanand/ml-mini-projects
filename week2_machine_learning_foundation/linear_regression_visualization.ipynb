# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Data
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([40, 50, 60, 65, 80])

# Train
model = LinearRegression()
model.fit(X, y)

# Predict
y_pred = model.predict(X)

# Plot
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, y_pred, color='red', label='Predicted Line')
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title('Linear Regression Visualization')
plt.legend()
plt.show()

print(f"Slope: {model.coef_[0]:.2f}")
print(f"Intercept: {model.intercept_:.2f}")

for i in range(len(X)):
    print(f"Hours: {X[i][0]}, Predicted: {y_pred[i]:.1f}, Actual: {y[i]}")
# Out:
# Slope: 9.50
# Intercept: 30.50
# Hours: 1, Predicted: 40.0, Actual: 40
# Hours: 2, Predicted: 49.5, Actual: 50
# Hours: 3, Predicted: 59.0, Actual: 60
# Hours: 4, Predicted: 68.5, Actual: 65
# Hours: 5, Predicted: 78.0, Actual: 80
